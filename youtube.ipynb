# %%
# created on April 14, 2021
# modified on Jan 2, 2022
# modified on April 20, 2023
# modified on January 5, 2024
# @author:          Bo Zhao
# @email:           zhaobo@uw.edu
# @website:         https://hgis.uw.edu
# @organization:    Department of Geography, University of Washington, Seattle
# @description:     A demo of collecting data from YouTube.

# %%
# Install and configure selenium on Google Colab that is built on Ubuntu 18.04.
# To install selenium, you will need to update ubuntu, install some dependencies, and install chromedriver.
# selenium is a Python package that allows you to automate your browser.
# chromedriver is a program that allows you to control Chrome from Python.
# chromedriver_autoinstaller is a Python package that automatically installs chromedriver; it can help you determine which version of chromedriver to install based on your version of Chrome.
# %%shell means that the following code is a shell script.
# %%shell
sudo apt -y update
sudo apt install -y wget curl unzip
wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
dpkg -i libu2f-udev_1.1.4-1_all.deb
wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
dpkg -i google-chrome-stable_current_amd64.deb

pip install selenium chromedriver_autoinstaller
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [23.8 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [665 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,060 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,677 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,391 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,326 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,722 kB]
# Get:17 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [44.4 kB]
# Get:18 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [66.2 kB]
# Fetched 8,235 kB in 5s (1,544 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 83 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# curl is already the newest version (7.81.0-1ubuntu1.15).
# unzip is already the newest version (6.0-26ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 83 not upgraded.
# --2024-01-29 19:44:41--  http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 185.125.190.39, 91.189.91.82, 91.189.91.81, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|185.125.190.39|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3708 (3.6K) [application/x-debian-package]
# Saving to: ‘libu2f-udev_1.1.4-1_all.deb’
#
# libu2f-udev_1.1.4-1 100%[===================>]   3.62K  --.-KB/s    in 0s
#
# 2024-01-29 19:44:42 (286 MB/s) - ‘libu2f-udev_1.1.4-1_all.deb’ saved [3708/3708]
#
# Selecting previously unselected package libu2f-udev.
# (Reading database ... 121671 files and directories currently installed.)
# Preparing to unpack libu2f-udev_1.1.4-1_all.deb ...
# Unpacking libu2f-udev (1.1.4-1) ...
# Setting up libu2f-udev (1.1.4-1) ...
# --2024-01-29 19:44:43--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 64.233.182.91, 64.233.182.190, 64.233.182.93, ...
# Connecting to dl.google.com (dl.google.com)|64.233.182.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106421968 (101M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>] 101.49M  55.2MB/s    in 1.8s
#
# 2024-01-29 19:44:45 (55.2 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [106421968/106421968]
#
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 121675 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (121.0.6167.85-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libvulkan1; however:
#   Package libvulkan1 is not installed.
#
# dpkg: error processing package google-chrome-stable (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for man-db (2.10.2-1) ...
# Errors were encountered while processing:
#  google-chrome-stable
# Collecting selenium
#   Downloading selenium-4.17.2-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 28.6 MB/s eta 0:00:00
# Collecting chromedriver_autoinstaller
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 35.7 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.11.17)
# Collecting typing_extensions>=4.9.0 (from selenium)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from chromedriver_autoinstaller) (23.2)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: typing_extensions, outcome, h11, chromedriver_autoinstaller, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed chromedriver_autoinstaller-0.6.4 h11-0.14.0 outcome-1.3.0.post0 selenium-4.17.2 trio-0.24.0 trio-websocket-0.11.1 typing_extensions-4.9.0 wsproto-1.2.0

# %%
from bs4 import BeautifulSoup # Import BeautifulSoup to parse the HTML.
import time, datetime # Import time and datetime to record the time.
import pandas as pd # Import pandas to create a dataframe, and it can save the dataframe as a csv file.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

chrome_options = Options() # Create an instance of Options so you can add arguments to the driver.
chrome_options.add_argument('--headless') # Add an argument 'headless' to run Chrome in headless mode.
chrome_options.add_argument('--no-sandbox') # Add an argument 'no-sandbox' to run Chrome in no-sandbox mode.
chrome_options.add_argument('--disable-dev-shm-usage') # Add an argument 'disable-dev-shm-usage' to run Chrome in disable-dev-shm-usage mode.

bot = webdriver.Chrome(options=chrome_options) # Create an instance of Chrome. Pass the argument 'options' to the constructor of Chrome.

# %%
search_terms = ["climate change", "global warming", "environmental issues"]

video_urls = []
results = []

for search_term in search_terms:
    url = "https://www.youtube.com/results?search_query=" + search_term.replace(" ", "+")
    bot.get(url)

    for i in range(5):
        soup = BeautifulSoup(bot.page_source, 'html.parser')
        videos = soup.find_all('ytd-video-renderer', class_="style-scope ytd-item-section-renderer")[-20:]

        for video in videos:
            try:
                video_url = video.find("a", class_="yt-simple-endpoint style-scope ytd-video-renderer").attrs["href"]
                user_url = video.find("a", class_="yt-simple-endpoint style-scope yt-formatted-string").attrs["href"]
                username = video.find("a", class_="yt-simple-endpoint style-scope yt-formatted-string").text
                title = video.find("yt-formatted-string", class_="style-scope ytd-video-renderer").text
                metadata_items = video.find_all("span", class_="inline-metadata-item style-scope ytd-video-meta-block")
                view_num = metadata_items[0].text.replace(" views", "")
                created_at = metadata_items[1].text.replace(" ago", "")
                shortdesc = video.find("yt-formatted-string", class_="metadata-snippet-text style-scope ytd-video-renderer").text
                collected_at = datetime.datetime.now()

                row = {'video_url': video_url,
                        'user_url': user_url,
                        'username': username,
                        'title': title,
                        'view_num': view_num,
                        'created_at': created_at,
                        'shortdesc': shortdesc,
                        'collected_at': collected_at}

                if video_url in video_urls:
                    print("this video has already been added.")
                else:
                    print(row)
                    video_urls.append(video_url)
                    results.append(row)
            except:
                pass

        time.sleep(5)
        bot.execute_script('window.scrollTo(0,  document.getElementById("content").scrollHeight);')

bot.close()

df = pd.DataFrame(results)

from google.colab import drive
drive.mount('/gdrive')

output_file = '/gdrive/My Drive/videos.csv'

df.to_csv(output_file, index=False)

print("the crawling task is finished.")

from google.colab import files
files.download(output_file)
print("the csv has been downloaded to your local computer. The program has been completed successfully.")
# Out:
# {'video_url': '/watch?v=9Ic0klFqawU&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@DWTravel', 'username': 'DW Travel', 'title': 'Winter Sports: How Climate Change Is Affecting Ski Resorts', 'view_num': '6.4K', 'created_at': '1 day', 'shortdesc': 'The Alps have always been a safe bet for skiers—until now. As a consequence of climate change, there is less snow, and slopes\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 36, 861566)}
# {'video_url': '/watch?v=X3imskGGXtw&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@NBCNews', 'username': 'NBC News', 'title': 'Study shows flooding in San Diego amplified by climate change', 'view_num': '23K', 'created_at': '2 days', 'shortdesc': 'Severe flooding that is occurring in many places in the U.S., like San Diego, California, are being amplified by climate change,\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 36, 868419)}
# {'video_url': '/watch?v=dcBXmj1nMTQ&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@aljazeeraenglish', 'username': 'Al Jazeera English', 'title': 'What is Climate Change? | Start Here', 'view_num': '1.4M', 'created_at': '4 years', 'shortdesc': 'The hard facts about global warming - a defining issue of our time. Climate change is happening now, and even world leaders\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 36, 870689)}
# {'video_url': '/watch?v=pEt6-jA2UE4&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@DWDocumentary', 'username': 'DW Documentary', 'title': 'Climate change - Averting catastrophe | DW Documentary', 'view_num': '2.1M', 'created_at': '6 months', 'shortdesc': 'In the last 30 years, CO2 emissions have increased by 60 percent worldwide. The most pressing problem facing our civilization is\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 36, 878439)}
# {'video_url': '/watch?v=EtW2rrLHs08&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@NatGeo', 'username': 'National Geographic', 'title': 'Climate Change 101 with Bill Nye | National Geographic', 'view_num': '2.8M', 'created_at': '8 years', 'shortdesc': "About National Geographic's 101 Series: Explore and experience the forces that shape the world around us. Get More National\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 36, 882074)}
# this video has already been added.
# this video has already been added.
# this video has already been added.
# this video has already been added.
# this video has already been added.
# {'video_url': '/watch?v=wkqDJwTIg_E&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@pbsterra', 'username': 'PBS Terra', 'title': "Earth's Temperature Has Changed WILDLY, So What's the Big Deal About a Few Degrees?", 'view_num': '140K', 'created_at': '1 month', 'shortdesc': "If you take a look at global temperature graphs that span millions or billions of years, you can see that our planet's temperature\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 43, 988803)}
# {'video_url': '/watch?v=LxgMdjyw8uw&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@kurzgesagt', 'username': 'Kurzgesagt – In a Nutshell', 'title': 'We WILL Fix Climate Change!', 'view_num': '10M', 'created_at': '1 year', 'shortdesc': 'Our home is burning. Rapid climate change is destabilizing our world. It seems our emissions will not fall quickly enough to avoid\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 43, 999961)}
# {'video_url': '/watch?v=gX3vtpUqwk8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ADDvanced', 'username': 'ADDvanced', 'title': 'WORST SEASON EVER:  The Future of Snowmobiling & Climate Change', 'view_num': '2.7K', 'created_at': '1 day', 'shortdesc': 'Will snowmobiling have a future? While I sit around watching all of our snow melt in one of the worst snowmobiling seasons in\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 9378)}
# {'video_url': '/watch?v=J1KGnCj_cfM&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@SabineHossenfelder', 'username': 'Sabine Hossenfelder', 'title': 'How do we know climate change is caused by humans?', 'view_num': '231K', 'created_at': '4 days', 'shortdesc': 'In this video I summarize the main pieces of evidence that we have which show that climate change is caused by humans. This is\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 12487)}
# {'video_url': '/watch?v=QlQ-MEZgRGY&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@environmentcan', 'username': 'Environment and Climate Change Canada', 'title': 'What is Climate Change?', 'view_num': '322K', 'created_at': '2 years', 'shortdesc': "Everyone's talking about climate change but what is our climate? And why is it changing? Our climate has been changing much\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 15979)}
# {'video_url': '/watch?v=Y1mPWVzaGQY&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@crashcourse', 'username': 'CrashCourse', 'title': 'What is Climate Change?: Crash Course Biology #8', 'view_num': '66K', 'created_at': '5 months', 'shortdesc': "Life on Earth has weathered boiling-hot oceans and volcanic-ash-darkened skies—but that's nothing like the climate change\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 21212)}
# {'video_url': '/watch?v=tMwFNMfjFuU&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@crashcourse', 'username': 'CrashCourse', 'title': 'What is Climate Change? Crash Course Geography #14', 'view_num': '284K', 'created_at': '2 years', 'shortdesc': "Today we're going to talk about climate change which is when there is a change in the average weather patterns in a region over\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 30804)}
# {'video_url': '/watch?v=3n69omzUFvM&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@SabineHossenfelder', 'username': 'Sabine Hossenfelder', 'title': 'Reality is worse than climate models predict, new study finds', 'view_num': '166K', 'created_at': '6 days', 'shortdesc': "In recent years, these events have frequently been attributed to climate change. This “extreme event attribution” how it's called is a\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 40932)}
# {'video_url': '/shorts/gwsFmhjZXs0', 'user_url': '/channel/UCqksHV6MVMSu4T2BMFk3nmQ', 'username': 'Emerson Brophy', 'title': "What if climate change isn't real?", 'view_num': '2M', 'created_at': '2 years', 'shortdesc': 'Of course climate change is very real, apparent and terrifying. Please use this to understand how an underreaction to it is way\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 44917)}
# {'video_url': '/watch?v=k3-BKwuDShc&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@WION', 'username': 'WION', 'title': 'Climate change: 2023 smashes records for surface temperature and ocean heat | WION', 'view_num': '3.5K', 'created_at': '2 weeks', 'shortdesc': 'The seas are the most obvious sign of global warming because they absorb 90% of the heat that is trapped by carbon emissions\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 47421)}
# {'video_url': '/watch?v=eAh9awb5968&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ABCNews', 'username': 'ABC News', 'title': 'A collaboration of scientists is sounding the alarm on climate change', 'view_num': '90K', 'created_at': '4 months', 'shortdesc': 'The World Weather Attribution just released a report saying human-caused climate change played a big role in the catastrophic\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 59205)}
# {'video_url': '/watch?v=E6bVBH9y5O8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@besmart', 'username': 'Be Smart', 'title': 'The Biggest Myth About Climate Change', 'view_num': '813K', 'created_at': '1 year', 'shortdesc': "You've seen it in the comment section before: “Climate change is natural. It's happened before and it will keep happening”.", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 63033)}
# {'video_url': '/watch?v=IJoAcD0oUww&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@SmileandLearnEnglish', 'username': 'Smile and Learn - English', 'title': 'Climate Change - The environment for Kids (Updated Version)', 'view_num': '395K', 'created_at': '3 years', 'shortdesc': 'Educational video for children to learn what climate change is, what can we do to stop it and take better care of our planet.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 44, 73470)}
# {'video_url': '/shorts/qP5snsmmpEc', 'user_url': '/@CNN', 'username': 'CNN', 'title': "Christie reacts to Ramaswamy's climate change claims", 'view_num': '907K', 'created_at': '5 months', 'shortdesc': 'A question on climate change quickly turned personal between Republican presidential candidates Vivek Ramaswamy and Chris\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 104613)}
# {'video_url': '/watch?v=qySBQjSXbfw&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@DWDocumentary', 'username': 'DW Documentary', 'title': 'Wind and climate change | DW Documentary', 'view_num': '1.7M', 'created_at': '1 year', 'shortdesc': 'Shifting wind patterns are making extreme weather events more likely. This is because the wind, which distributes areas of high\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 108441)}
# {'video_url': '/shorts/8n36krG_b4s', 'user_url': '/@Officialjadenwilliams', 'username': 'Jaden Williams', 'title': 'Let HIM COOK 🔥 #skit #funny #climatechange', 'view_num': '13M', 'created_at': '8 months', 'shortdesc': "... sandals made from rubber I bet you posted this meat on Facebook didn't you sure seems you're awful climate change if you ask\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 110224)}
# {'video_url': '/watch?v=d4LWK2Qgyyw&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@PBSNewsHour', 'username': 'PBS NewsHour', 'title': 'Latest climate assessment reveals how much climate change is costing Americans', 'view_num': '22K', 'created_at': '2 months', 'shortdesc': 'The National Climate Assessment shows America is warming faster than the global average with climate change impacting nearly\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 112409)}
# {'video_url': '/watch?v=IhtysFlWz3k&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@globalnews', 'username': 'Global News', 'title': 'Earth breaches critical warming threshold', 'view_num': '22K', 'created_at': '2 months', 'shortdesc': 'There is a new, troubling indicator about global warming from the Copernicus Climate Change Service (C3S). The service says\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 113932)}
# {'video_url': '/watch?v=cn9PhiDJp-A&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@Hopscotchsongs', 'username': 'Hopscotch', 'title': 'Climate Change Song', 'view_num': '4.8M', 'created_at': '2 years', 'shortdesc': 'Song by Matt & Joanna Pace, in partnership with Octopus Electric Vehicles Video animated by Dakota Sheperd and Jason McNeil\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 115208)}
# {'video_url': '/watch?v=acyErLNL7kQ&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@HooverInstitution', 'username': 'Hoover Institution', 'title': 'Steven Koonin on The Limitations of Climate Change Models', 'view_num': '118K', 'created_at': '3 months', 'shortdesc': 'Steven Koonin reviews the state of climate science, focusing on data trends, climate models, and the uncertainties involved.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 117299)}
# {'video_url': '/watch?v=oJWX3jVhrqg&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@TEDx', 'username': 'TEDx Talks', 'title': 'Facing the New Inconvenient Truth: Climate Change is Upon Us | David Mc Cauley | TEDxOltrarno', 'view_num': '599K', 'created_at': '3 months', 'shortdesc': 'David Mc Cauley highlights the growing risks posed by our rapidly changing climate and the need to ramp up individual,\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 118834)}
# {'video_url': '/watch?v=w-rEQLJEyTs&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@SimonClark', 'username': 'Simon Clark', 'title': '2023: A Year In Climate Change', 'view_num': '59K', 'created_at': '1 month', 'shortdesc': 'REFERENCES www.simonoxfphys.com/blog/2023/12/22/references-for-my-2023-review-of-climate-change-news ---------- II\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 120276)}
# {'video_url': '/watch?v=DkZ7BJQupVA&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@Vox', 'username': 'Vox', 'title': 'Why humans are so bad at thinking about climate change', 'view_num': '2.4M', 'created_at': '6 years', 'shortdesc': "The biggest problem for the climate change fight isn't technology – it's human psychology. This is the first episode of Climate Lab,\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 122211)}
# {'video_url': '/watch?v=5CbGpWlPXws&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@NBCNews', 'username': 'NBC News', 'title': 'Will climate change ever be a bipartisan issue?', 'view_num': '3.1K', 'created_at': '4 days', 'shortdesc': 'From flooding, to wildfires, to increasing temperatures, climate change has become a prevalent issue as more Americans, even\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 123602)}
# {'video_url': '/watch?v=G4H1N_yXBiA&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@NatGeo', 'username': 'National Geographic', 'title': 'Causes and Effects of Climate Change | National Geographic', 'view_num': '4.7M', 'created_at': '6 years', 'shortdesc': "About National Geographic: National Geographic is the world's premium destination for science, exploration, and adventure.", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 125439)}
# {'video_url': '/shorts/cKgAiWVnk6E', 'user_url': '/@besmart', 'username': 'Be Smart', 'title': 'Climate change is turning sea turtles FEMALE?!', 'view_num': '615K', 'created_at': '3 weeks', 'shortdesc': 'Another YouTube #shorts from your favorite science dad, Dr. Joe! Join us on Patreon! https://patreon.com/itsokaytobesmart\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 126804)}
# {'video_url': '/watch?v=yiw6_JakZFc&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@kurzgesagt', 'username': 'Kurzgesagt – In a Nutshell', 'title': 'Can YOU Fix Climate Change?', 'view_num': '13M', 'created_at': '2 years', 'shortdesc': 'Never before in human history have we been richer, more advanced or powerful. And yet we feel overwhelmed in the face of rapid\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 128658)}
# {'video_url': '/watch?v=uynhvHZUOOo&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@TheEconomist', 'username': 'The Economist', 'title': 'See what three degrees of global warming looks like', 'view_num': '3.6M', 'created_at': '2 years', 'shortdesc': '00:57 - Climate change is already having devastating effects 02:58 - How climate modelling works 04:06 - Nowhere is safe from\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 130082)}
# {'video_url': '/watch?v=ScX29WBJI3w&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@EPAgov', 'username': 'U.S. Environmental Protection Agency', 'title': 'Climate Change Basics (OLD)', 'view_num': '829K', 'created_at': '8 years', 'shortdesc': 'NOTE: If you need captions, please click the CC button on the player to turn them on. This video provides an introduction to the\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 131763)}
# {'video_url': '/watch?v=DqJpQ_UUmWM&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ClimateAdam', 'username': 'ClimateAdam', 'title': 'Will 2024 be the Hottest Year Ever Recorded?', 'view_num': '20K', 'created_at': '2 weeks', 'shortdesc': '2023 shattered global temperature records, as climate change coupled with El Niño raised temperatures to sweltering levels.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 133097)}
# {'video_url': '/watch?v=dpvd9FensT8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@astrumspace', 'username': 'Astrum', 'title': 'This Will Be My Most Disliked Video On YouTube | Climate Change', 'view_num': '2.9M', 'created_at': '4 months', 'shortdesc': "Become a Patron today and support my channel! Donate link above. I can't do it without you. Thanks to those who have supported\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 134382)}
# {'video_url': '/watch?v=G9t__9Tmwv4&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@Scienceabc', 'username': 'Science ABC', 'title': 'Climate Change and Global Warming: Explained in Simple Words for Beginners', 'view_num': '166K', 'created_at': '1 year', 'shortdesc': 'The term climate change is used to denote the long-term changes in the weather patterns in a given region. Another term often\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 136413)}
# {'video_url': '/watch?v=MBKZWKeKYqE&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@pbsterra', 'username': 'PBS Terra', 'title': 'What Will Earth Look Like When These 6 Tipping Points Hit?', 'view_num': '1.4M', 'created_at': '1 year', 'shortdesc': 'A “tipping point” is when a system, with just a small amount of additional energy, is pushed from one stable state to another\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 46, 52, 137748)}
# {'video_url': '/watch?v=ztWHqUFJRTs&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@TEDEd', 'username': 'TED-Ed', 'title': "Climate change: Earth's giant game of Tetris - Joss Fong", 'view_num': '1.1M', 'created_at': '9 years', 'shortdesc': "There's a game of Tetris happening on a global scale: The playing space is planet Earth, and all those pesky, stacking blocks\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 545675)}
# {'video_url': '/watch?v=eHMLszamZ9w&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@SiemensKnowledgeHub', 'username': 'Siemens Knowledge Hub', 'title': 'What is climate change?', 'view_num': '282K', 'created_at': '6 years', 'shortdesc': "1. Episode: What is climate change and is it real? Climate Change is the bad news story that isn't going away From heatwaves to\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 547779)}
# {'video_url': '/watch?v=DjUr2HwdHwg&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@OurChangingClimate', 'username': 'Our Changing Climate', 'title': 'Why We Need Socialism', 'view_num': '221K', 'created_at': '2 weeks', 'shortdesc': 'In this Our Changing Climate climate change video essay, I look a how and why socialism, specifically ecosocialism, is crucial to\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 549785)}
# {'video_url': '/watch?v=myZAvqqp9Jc&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ClimateScience', 'username': 'ClimateScience - Solve Climate Change', 'title': 'Climate Change: How does it really work? | ClimateScience #1', 'view_num': '111K', 'created_at': '3 years', 'shortdesc': "You've seen it in the news, heard it on the radio, maybe you even heard about it on TikTok but are you sure you truly know what\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 551550)}
# {'video_url': '/shorts/QUCT90DyBh0', 'user_url': '/@besmart', 'username': 'Be Smart', 'title': 'Climate Change explained in less than 1 minute!', 'view_num': '323K', 'created_at': '1 year', 'shortdesc': 'Another YouTube #shorts from your favorite science dad, Dr. Joe Sources: https://ourworldindata.org/atmospheric-concentrations\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 552931)}
# {'video_url': '/watch?v=9PFhrpyWV-w&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@crashcourse', 'username': 'CrashCourse', 'title': 'What is Climate Change?: Crash Course Climate & Energy #1', 'view_num': '156K', 'created_at': '1 year', 'shortdesc': 'We know that temperatures on Earth have fluctuated dramatically in the past, but we also know that by burning fossil fuels we are\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 554928)}
# {'video_url': '/watch?v=SLEenW2UiUw&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@BBCWorldService', 'username': 'BBC World Service', 'title': 'What is climate change? - The Climate Question, BBC World Service', 'view_num': '193K', 'created_at': '2 months', 'shortdesc': 'Looking for a climate change 101? Here to help you brush up on the basics is Jordan Dunbar. Click here to subscribe to our\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 556858)}
# {'video_url': '/shorts/ysNv46MjCR8', 'user_url': '/@Channel4News', 'username': 'Channel 4 News', 'title': 'Final warning on climate change', 'view_num': '56K', 'created_at': '10 months', 'shortdesc': 'UN scientists have given what they say is a final warning for how to save the planet from disastrous climate change. (Subscribe:\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 558297)}
# {'video_url': '/watch?v=Tx0am8PdoOs&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@GeologyUpSkill', 'username': 'GeologyUpSkill', 'title': 'Geologists See Climate Change Differently', 'view_num': '306K', 'created_at': '3 weeks', 'shortdesc': 'This place explains why geologists see the climate change from a different perspective.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 559528)}
# {'video_url': '/shorts/5ktYj9xKbDI', 'user_url': '/@Hopscotchsongs', 'username': 'Hopscotch', 'title': 'Climate Change Song, Sing-along with us', 'view_num': '229K', 'created_at': '10 months', 'shortdesc': 'A song to help kids learn about climate change and how to care for our earth. "Let\'s switch to renewable power, unplug and take\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 560869)}
# {'video_url': '/watch?v=8eJ-TFIlLK0&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ClimateAdam', 'username': 'ClimateAdam', 'title': 'Could Climate Change cause an Ocean Tipping Point... Soon..?', 'view_num': '35K', 'created_at': '5 months', 'shortdesc': 'The huge ocean current known as the Atlantic Meridional Overturning Circulation (AMOC - not the Gulf Stream!) shifts vast amount\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 566604)}
# {'video_url': '/watch?v=l_Oe6YK0DgE&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@pbsterra', 'username': 'PBS Terra', 'title': 'What is the RISKIEST Region in the US as the Climate Changes?', 'view_num': '2.7M', 'created_at': '1 year', 'shortdesc': 'Climate Change is increasing the frequency and severity of natural disasters all around the world. And in the United States, more\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 567921)}
# {'video_url': '/watch?v=WkvPdUtYhX8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@LearnBright', 'username': 'Learn Bright', 'title': 'Climate Change for Kids | A fun engaging introduction to climate change for kids', 'view_num': '433K', 'created_at': '2 years', 'shortdesc': 'Hey Teachers and Parents! In this video we explore climate change for kids. We learn all about the causes of climate change like\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 569933)}
# {'video_url': '/watch?v=zy7vUppYPC8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@DWDocumentary', 'username': 'DW Documentary', 'title': 'Will renewables stop the climate crisis? | DW Documentary', 'view_num': '198K', 'created_at': '1 month', 'shortdesc': 'Mankind is facing the greatest upheaval since industrialization. To stop climate change, the energy system must be transformed\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 572015)}
# {'video_url': '/watch?v=EbjKcHPmxKQ&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@Vox', 'username': 'Vox', 'title': 'What people get wrong about climate change', 'view_num': '930K', 'created_at': '8 years', 'shortdesc': "When discussing climate change, it's not about saving the planet. Subscribe to our channel! http://goo.gl/0bsAjO One of the\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 573446)}
# {'video_url': '/shorts/iRlnSMcCKSY', 'user_url': '/@LXNews', 'username': 'LX News', 'title': 'Climate Change Protestors Glue Their Hands to the Road', 'view_num': '266K', 'created_at': '9 months', 'shortdesc': "That's one way to stick to your plan! #protest #climatechange #shorts Subscribe:\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 574771)}
# {'video_url': '/watch?v=ldLBoErAhz4&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@eons', 'username': 'PBS Eons', 'title': 'The Last Time the Globe Warmed', 'view_num': '8.6M', 'created_at': '6 years', 'shortdesc': 'Imagine an enormous, lush rainforest teeming with life...in the Arctic. Well, there was a time -- and not too long ago -- when the\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 576189)}
# {'video_url': '/watch?v=t7IpV3PjACY&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@CBSNews', 'username': 'CBS News', 'title': "Arctic melting foreshadows America's climate future", 'view_num': '25K', 'created_at': '1 month', 'shortdesc': 'What scientists are learning there can help Americans understand how climate change is affecting our country too. CBS News\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 577653)}
# {'video_url': '/watch?v=-Vm_gabtIA8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@CNBC', 'username': 'CNBC', 'title': 'Which U.S. Cities Are Safest From Climate Change?', 'view_num': '784K', 'created_at': '1 year', 'shortdesc': 'Climate havens or climate destinations are cities that are situated in places that avoid the worst effects of natural disasters and\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 579704)}
# {'video_url': '/watch?v=vFDnknU0h0s&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@pbsterra', 'username': 'PBS Terra', 'title': "Have We Made ANY Progress on Climate Change? Here's The Data, You Decide", 'view_num': '290K', 'created_at': '1 year', 'shortdesc': 'RCP 8.5 has often been referred to as “business as usual.” It describes a world without action on climate policy and continued\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 2, 581029)}
# {'video_url': '/shorts/GyXUnbkBG-4', 'user_url': '/@YahooFinance', 'username': 'Yahoo Finance', 'title': 'Biden on climate change: Our bad 🇺🇸 #shorts', 'view_num': '41K', 'created_at': '7 months', 'shortdesc': "President Biden addressed climate change and referred to China's international investments under the Belt and Road Initiative\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 816065)}
# {'video_url': '/watch?v=PvvmGkBI2bU&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ForbesBreakingNews', 'username': 'Forbes Breaking News', 'title': "Sheldon Whitehouse: Climate Change Is Causing 'Dramatic Changes' In The Oceans", 'view_num': '1K', 'created_at': '4 days', 'shortdesc': 'At a Senate Budget Committee hearing on Wednesday, Sen. Sheldon Whitehouse (D-RI) spoke about how climate change is\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 817563)}
# {'video_url': '/watch?v=6Ua6IUZKN58&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@TEDx', 'username': 'TEDx Talks', 'title': 'The Paradox of Climate Change | Marshall Brain | TEDxNCState', 'view_num': '5.4K', 'created_at': '2 months', 'shortdesc': 'Marshall Brain explains how humanity faces a gigantic threat from the many effects that climate change is having on the planet.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 819025)}
# {'video_url': '/shorts/pLVdV9jWfSo', 'user_url': '/@SimonClark', 'username': 'Simon Clark', 'title': 'Is there actually any evidence for climate change? #science', 'view_num': '3.6M', 'created_at': '5 months', 'shortdesc': '... atmospheric Oceanic cryological biological chemical and migratory evidence is there really any evidence for climate change.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 820445)}
# {'video_url': '/watch?v=N6t6QHQtdVw&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@Peekaboo_Kidz', 'username': 'Peekaboo Kidz', 'title': 'Climate Change 101 | Keep The Environment Safe | The Dr Binocs Show | Peekaboo Kidz', 'view_num': '1.1M', 'created_at': '1 year', 'shortdesc': 'Climate | How To Keep The Environment Safe? | Global Warming | Climate Change | What Causes Global Warming?', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 822256)}
# {'video_url': '/shorts/Ekw3nBuqbf0', 'user_url': '/@NasDaily', 'username': 'Nas Daily', 'title': 'How I Touched Climate Change #486', 'view_num': '2.7M', 'created_at': '8 months', 'shortdesc': 'I saw icebergs breaking and melting - with my own eyes! When you see it, you can finally believe it. This is it for Greenland. I hope\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 823712)}
# {'video_url': '/watch?v=zG53kU3gIa4&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@GlobalLandscapesForum', 'username': 'Global Landscapes Forum - GLF', 'title': 'Top 10 Climate Change Myths BUSTED', 'view_num': '52K', 'created_at': '1 year', 'shortdesc': 'Is climate change real – and are humans causing it? Myths about climate change are more pervasive than ever, which is why\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 825711)}
# {'video_url': '/watch?v=GWOu4nuxhw8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@CBSNews', 'username': 'CBS News', 'title': 'The impact of climate change on severe weather', 'view_num': '16K', 'created_at': '1 month', 'shortdesc': 'In this episode of “Protecting the Planet,” CBS News senior environmental correspondent Ben Tracy explores the connection\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 827606)}
# {'video_url': '/watch?v=FM84zkqY8ZA&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@dwnews', 'username': 'DW News', 'title': 'Keeping the peace as climate change fuels conflict in Africa | DW News', 'view_num': '11K', 'created_at': '1 day', 'shortdesc': "The Sahel is one of the world's most vulnerable areas to climate change. Intense drought and flooding are common in the region\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 828967)}
# {'video_url': '/watch?v=oJAbATJCugs&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@NatGeo', 'username': 'National Geographic', 'title': 'Global Warming 101 | National Geographic', 'view_num': '5.3M', 'created_at': '16 years', 'shortdesc': "#NationalGeographic #GlobalWarming #Educational About National Geographic's 101 Series: Explore and experience the forces\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 830258)}
# {'video_url': '/watch?v=vjZnUl3OkCI&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@EnglishSpeakingSuccess', 'username': 'English Speaking Success', 'title': 'How to talk about CLIMATE CHANGE in English', 'view_num': '635K', 'created_at': '2 years', 'shortdesc': "_____ How do you talk about Climate Change in English and with confidence? …let's find out. I am going to take you on a rather\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 832092)}
# {'video_url': '/watch?v=lThF3JOaYV8&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@Reuters', 'username': 'Reuters', 'title': "Climate change drives Amazon's drought: study | REUTERS", 'view_num': '931', 'created_at': '4 days', 'shortdesc': 'Climate change is the main culprit for a record drought in the Amazon rainforest that has drained rivers, killed endangered\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 833457)}
# {'video_url': '/shorts/Re5jtsyhDFA', 'user_url': '/@msnbc', 'username': 'MSNBC', 'title': 'Bill Nye on how to address climate change', 'view_num': '232K', 'created_at': '5 months', 'shortdesc': 'Bill Nye invokes the film "Oppenheimer" when explaining how we should address climate change. » Subscribe to MSNBC:\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 835327)}
# {'video_url': '/watch?v=EuwMB1Dal-4&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ClickView', 'username': 'ClickView', 'title': 'What is Climate Change? Explore the Causes of Climate Change', 'view_num': '400K', 'created_at': '2 years', 'shortdesc': 'This video defines climate change and explains the greenhouse effect and the role of greenhouse gases in our atmosphere.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 837171)}
# {'video_url': '/shorts/VKA_hDzdBSY', 'user_url': '/@CBCTheNational', 'username': 'CBC News: The National', 'title': 'Climate change is changing Canadian winters', 'view_num': '16K', 'created_at': '2 years', 'shortdesc': 'New climate data out this week shows that 2021 was a hot year — the sixth hottest on record, according to NASA. Probably not\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 838594)}
# {'video_url': '/watch?v=dXw9_m8fN-s&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/channel/UC11YzVs4e4h9kIt4VzUS6yQ', 'username': 'Oli Frost', 'title': 'The Dragon of Climate Change (Music Video)', 'view_num': '48K', 'created_at': '1 year', 'shortdesc': "Lyrics: There once was a terrible dragon Whose name was climate change He slept atop a mountain As he'd done for an age 'Til\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 839936)}
# {'video_url': '/watch?v=Lq0iua0r0KQ&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@OxfordUnion', 'username': 'OxfordUnion', 'title': 'Climate Change Debate | Kriti Joshi | Opposition', 'view_num': '4.8M', 'created_at': '7 years', 'shortdesc': 'The Motion: This House Believes The West Has No Right to Impose Environmental Standards on Developing Countries Kriti Joshi\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 841301)}
# {'video_url': '/watch?v=Wpy4xBftFuY&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@BBCNews', 'username': 'BBC News', 'title': "Arnold Schwarzenegger calls leaders 'liars' over climate change - BBC News", 'view_num': '988K', 'created_at': '2 years', 'shortdesc': 'Actor and former governor of California, Arnold Schwarzenegger, has become a champion of clean air and renewable energy,\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 842776)}
# {'video_url': '/watch?v=bJfrKNR3K2k&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@ForbesBreakingNews', 'username': 'Forbes Breaking News', 'title': "'What Percent Of Our Atmosphere Is CO2?': Doug LaMalfa Stumps Entire Panel With Climate Questions", 'view_num': '2.4M', 'created_at': '9 months', 'shortdesc': 'Rep. Doug LaMalfa (R-CA) questioned witnesses at a House Transportation Committee about the Infrastructure Investment and\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 844361)}
# {'video_url': '/watch?v=tqcDyHdbYd4&pp=ygUOY2xpbWF0ZSBjaGFuZ2U%3D', 'user_url': '/@telegraph', 'username': 'The Telegraph', 'title': 'Greta Thunberg’s climate crusade is heading for defeat | Michael Shellenberger interview', 'view_num': '475K', 'created_at': '2 months', 'shortdesc': 'Michael Shellenberger is an environmentalist, author, and advocate for pragmatic solutions to climate change. He joins Steven\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 14, 845809)}
# {'video_url': '/watch?v=oJAbATJCugs&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@NatGeo', 'username': 'National Geographic', 'title': 'Global Warming 101 | National Geographic', 'view_num': '5.3M', 'created_at': '16 years', 'shortdesc': "#NationalGeographic #GlobalWarming #Educational About National Geographic's 101 Series: Explore and experience the forces\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 193771)}
# {'video_url': '/watch?v=wkqDJwTIg_E&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@pbsterra', 'username': 'PBS Terra', 'title': "Earth's Temperature Has Changed WILDLY, So What's the Big Deal About a Few Degrees?", 'view_num': '140K', 'created_at': '1 month', 'shortdesc': "If you take a look at global temperature graphs that span millions or billions of years, you can see that our planet's temperature\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 196902)}
# {'video_url': '/watch?v=n5DXniZGkME&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@ABCNewsIndepth', 'username': 'ABC News In-depth', 'title': 'There are 8 billion people on Earth, but soon we’ll hit a decline we might never reverse | ABC News', 'view_num': '997K', 'created_at': '1 year', 'shortdesc': 'ABC News In-depth takes you deeper on the big stories, with long-form journalism from Four Corners, Foreign Correspondent,\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 199705)}
# {'video_url': '/watch?v=QAAbcNl4Lb8&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@frontline', 'username': 'FRONTLINE PBS | Official', 'title': 'The Power of Big Oil Part One: Denial (full documentary) | FRONTLINE', 'view_num': '2.5M', 'created_at': '1 year', 'shortdesc': 'Go inside the decades-long failure to confront the threat and increasing impacts of climate change in “The Power of Big Oil.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 202603)}
# {'video_url': '/watch?v=N6t6QHQtdVw&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@Peekaboo_Kidz', 'username': 'Peekaboo Kidz', 'title': 'Climate Change 101 | Keep The Environment Safe | The Dr Binocs Show | Peekaboo Kidz', 'view_num': '1.1M', 'created_at': '1 year', 'shortdesc': 'Climate | How To Keep The Environment Safe? | Global Warming | Climate Change | What Causes Global Warming?', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 206321)}
# {'video_url': '/watch?v=LwRTw_7NNJs&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@nasaclimatechange', 'username': 'NASA Climate Change', 'title': 'Global Warming from 1880 to 2022', 'view_num': '131K', 'created_at': '1 year', 'shortdesc': "Earth's average surface temperature in 2022 tied with 2015 as the fifth warmest on record, according to an analysis by NASA.", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 208742)}
# {'video_url': '/watch?v=uynhvHZUOOo&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@TheEconomist', 'username': 'The Economist', 'title': 'See what three degrees of global warming looks like', 'view_num': '3.6M', 'created_at': '2 years', 'shortdesc': "If global temperatures rise three degrees Celsius above pre-industrial levels, the results would be catastrophic. It's an entirely\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 212444)}
# {'video_url': '/watch?v=IhtysFlWz3k&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@globalnews', 'username': 'Global News', 'title': 'Earth breaches critical warming threshold', 'view_num': '22K', 'created_at': '2 months', 'shortdesc': 'There is a new, troubling indicator about global warming from the Copernicus Climate Change Service (C3S). The service says\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 215088)}
# {'video_url': '/watch?v=pEt6-jA2UE4&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@DWDocumentary', 'username': 'DW Documentary', 'title': 'Climate change - Averting catastrophe | DW Documentary', 'view_num': '2.1M', 'created_at': '6 months', 'shortdesc': 'In the last 30 years, CO2 emissions have increased by 60 percent worldwide. The most pressing problem facing our civilization is\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 217735)}
# {'video_url': '/watch?v=J1KGnCj_cfM&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@SabineHossenfelder', 'username': 'Sabine Hossenfelder', 'title': 'How do we know climate change is caused by humans?', 'view_num': '231K', 'created_at': '4 days', 'shortdesc': 'In this video I summarize the main pieces of evidence that we have which show that climate change is caused by humans. This is\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 220499)}
# {'video_url': '/watch?v=G9t__9Tmwv4&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@Scienceabc', 'username': 'Science ABC', 'title': 'Climate Change and Global Warming: Explained in Simple Words for Beginners', 'view_num': '166K', 'created_at': '1 year', 'shortdesc': 'The term climate change is used to denote the long-term changes in the weather patterns in a given region. Another term often\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 224315)}
# {'video_url': '/watch?v=9xCaalQeAbY&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@SimonClark', 'username': 'Simon Clark', 'title': 'Global Warming: The Century We Saved Earth', 'view_num': '61K', 'created_at': '1 month', 'shortdesc': "In this documentary I present a fictional, optimistic account of the 21st century, told retrospectively from the year 2100. This isn't\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 226869)}
# {'video_url': '/watch?v=LxgMdjyw8uw&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@kurzgesagt', 'username': 'Kurzgesagt – In a Nutshell', 'title': 'We WILL Fix Climate Change!', 'view_num': '10M', 'created_at': '1 year', 'shortdesc': 'Our home is burning. Rapid climate change is destabilizing our world. It seems our emissions will not fall quickly enough to avoid\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 229539)}
# {'video_url': '/watch?v=ldLBoErAhz4&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@eons', 'username': 'PBS Eons', 'title': 'The Last Time the Globe Warmed', 'view_num': '8.6M', 'created_at': '6 years', 'shortdesc': '... http://all-geo.org/highlyallochthonous/2010/01/coal-and-the-fossil-record-of-climate-change-in-the-canadian-high-arctic/\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 232311)}
# {'video_url': '/watch?v=sDS1sFg6lNw&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@NDTV', 'username': 'NDTV', 'title': 'Climate Change and Global Warming, EXPLAINED | The Climate Explainers', 'view_num': '77K', 'created_at': '7 months', 'shortdesc': 'In this episode of The Climate Explainers, Anubha Bhonsle explains the difference between climate change & global warming,\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 234953)}
# this video has already been added.
# {'video_url': '/watch?v=eAh9awb5968&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@ABCNews', 'username': 'ABC News', 'title': 'A collaboration of scientists is sounding the alarm on climate change', 'view_num': '90K', 'created_at': '4 months', 'shortdesc': 'The World Weather Attribution just released a report saying human-caused climate change played a big role in the catastrophic\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 240407)}
# {'video_url': '/watch?v=QlQ-MEZgRGY&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@environmentcan', 'username': 'Environment and Climate Change Canada', 'title': 'What is Climate Change?', 'view_num': '322K', 'created_at': '2 years', 'shortdesc': "Everyone's talking about climate change but what is our climate? And why is it changing? Our climate has been changing much\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 244326)}
# {'video_url': '/watch?v=w-rEQLJEyTs&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@SimonClark', 'username': 'Simon Clark', 'title': '2023: A Year In Climate Change', 'view_num': '59K', 'created_at': '1 month', 'shortdesc': 'REFERENCES www.simonoxfphys.com/blog/2023/12/22/references-for-my-2023-review-of-climate-change-news ---------- II\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 247312)}
# {'video_url': '/watch?v=tMwFNMfjFuU&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@crashcourse', 'username': 'CrashCourse', 'title': 'What is Climate Change? Crash Course Geography #14', 'view_num': '284K', 'created_at': '2 years', 'shortdesc': "Today we're going to talk about climate change which is when there is a change in the average weather patterns in a region over\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 31, 251302)}
# {'video_url': '/shorts/w_jWUZP6ssc', 'user_url': '/@dylanjardon', 'username': 'Dylan Jardon', 'title': 'How to Solve Global Warming (EASY)', 'view_num': '1.1M', 'created_at': '6 months', 'shortdesc': "Here's the easy way to solve global warming... Follow: ♪ https://www.tiktok.com/@smartnonsense\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 393531)}
# {'video_url': '/watch?v=8DiWzvE52ZY&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/channel/UC34wpCgr3l9cG0RtFdTTS-Q', 'username': 'Gojira', 'title': 'Gojira - Global Warming [Live at the Silver Cord Studio May 2018]', 'view_num': '8.4M', 'created_at': '5 years', 'shortdesc': 'A few weeks ago, we played Global Warming together for the first time since the recording of From Mars To Sirius (2004).', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 395023)}
# {'video_url': '/watch?v=MBKZWKeKYqE&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@pbsterra', 'username': 'PBS Terra', 'title': 'What Will Earth Look Like When These 6 Tipping Points Hit?', 'view_num': '1.4M', 'created_at': '1 year', 'shortdesc': '... points that scientists have grown increasingly worried we are getting close to crossing due to global warming. In this episode of\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 396392)}
# {'video_url': '/watch?v=Wq15eF5vCbI&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@SkyNews', 'username': 'Sky News', 'title': 'Track the impact of global warming on the world', 'view_num': '1.6M', 'created_at': '1 year', 'shortdesc': 'This data livestream shows in real time what is causing our environment to change. From the amount of carbon dioxide in our\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 397713)}
# {'video_url': '/watch?v=oqu5DjzOBF8&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@SabineHossenfelder', 'username': 'Sabine Hossenfelder', 'title': "I Misunderstood the Greenhouse Effect. Here's How It Works.", 'view_num': '780K', 'created_at': '11 months', 'shortdesc': 'Correction to what I say at 7 mins 13: The major reason air pressure decreases is that the gravitational pressure from the air above\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 399103)}
# {'video_url': '/watch?v=ah26x7nWmG8&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@SkyNews', 'username': 'Sky News', 'title': 'Global warming to hit 1.5C heat threshold by 2027', 'view_num': '25K', 'created_at': '8 months', 'shortdesc': 'The global temperature is set to exceed 1.5C above pre-industrial levels for the first time in the next five years, the World\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 400453)}
# {'video_url': '/watch?v=qySBQjSXbfw&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@DWDocumentary', 'username': 'DW Documentary', 'title': 'Wind and climate change | DW Documentary', 'view_num': '1.7M', 'created_at': '1 year', 'shortdesc': 'Shifting wind patterns are making extreme weather events more likely. This is because the wind, which distributes areas of high\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 401759)}
# {'video_url': '/watch?v=cn9PhiDJp-A&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@Hopscotchsongs', 'username': 'Hopscotch', 'title': 'Climate Change Song', 'view_num': '4.8M', 'created_at': '2 years', 'shortdesc': 'Song by Matt & Joanna Pace, in partnership with Octopus Electric Vehicles Video animated by Dakota Sheperd and Jason McNeil\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 402969)}
# {'video_url': '/watch?v=E6bVBH9y5O8&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@besmart', 'username': 'Be Smart', 'title': 'The Biggest Myth About Climate Change', 'view_num': '813K', 'created_at': '1 year', 'shortdesc': "You've seen it in the comment section before: “Climate change is natural. It's happened before and it will keep happening”.", 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 404901)}
# {'video_url': '/watch?v=jBQS00kgG8g&pp=ygUOZ2xvYmFsIHdhcm1pbmc%3D', 'user_url': '/@rausias1953', 'username': "Rau's IAS Study Circle (Since 1953)", 'title': "Global Warming & Climate Change | Explained | Gaurav Tripathi | Rau's IAS", 'view_num': '3.4K', 'created_at': '2 weeks', 'shortdesc': 'From greenhouse gases to melting glaciers, this video unpacks everything you need to know about global warming and climate\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 47, 39, 406260)}
# ...
# {'video_url': '/shorts/bh7-SKiI3n8', 'user_url': '/@ALBiodiversity', 'username': 'Biodiversity', 'title': 'Top 5 Environmental Issues', 'view_num': '201', 'created_at': '8 months', 'shortdesc': 'Original content. Credits HIPPO acronym, E.O. Wilson. Music Song: Hard Hitters Artist: Donell Mase.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 570874)}
# {'video_url': '/watch?v=x8Rxx3GkhKU&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@sciencebasics3064', 'username': 'Science Basics', 'title': 'Importance of Knowledge in Environmental Issues', 'view_num': '3.1K', 'created_at': '1 year', 'shortdesc': 'Philippine Environment Month Celebration KINAADMAN: Importance of Knowledge in Environmental Issues Time: Jun 5, 2021\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 573780)}
# {'video_url': '/watch?v=ABa-9fXyygw&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@nowthisimpact', 'username': 'NowThis Impact', 'title': 'Top 5 Environmental Issues Impacting Hispanic and Latine Communities', 'view_num': '3.6K', 'created_at': '1 year', 'shortdesc': 'For more environmental news subscribe to NowThis News. #hispanicheritagemonth #environment #environmental #Politics\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 577054)}
# {'video_url': '/watch?v=PrZTv5hBDc4&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@MyMukeshSir', 'username': 'Physics Gyaan Mukesh Nayak', 'title': 'Biodiversity, Conservation and Environmental Issues | One Shot Series | HSC Board-2023 | #biology', 'view_num': '13K', 'created_at': '1 year', 'shortdesc': 'Hello My Dear Students, Welcome To Our Channel... Hello my dear students, welcome to our channel. In this video we are going\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 580169)}
# {'video_url': '/watch?v=2Idq0jZDAFA&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@InternationalPartnershipsEU', 'username': 'EU International Partnerships', 'title': 'Environmental issues in Central Asia', 'view_num': '1.7K', 'created_at': '5 years', 'shortdesc': '90 sec. version.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 583021)}
# {'video_url': '/watch?v=xUojoq_aBPQ&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@electricenglish', 'username': 'Electric English', 'title': 'Environmental Issues MCQs Marathon For PSSSB Exams | Environmental Issues GK | Electric English', 'view_num': '4.3K', 'created_at': '7 months', 'shortdesc': 'Environmental Issues MCQs Marathon For PSSSB Clerk Cum Data Entry Operator || Electric English ✓Join the Official Telegram\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 585951)}
# {'video_url': '/watch?v=1U2o3o78o04&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@MagnetBrainsEducation', 'username': 'Magnet Brains', 'title': 'Class 12 Biology Chapter 16 | Introduction - Environmental Issues (2022-23)', 'view_num': '68K', 'created_at': '4 years', 'shortdesc': '=============================================== ✓ In this video, ✔️ Class: 12th ✔️ Subject: Biology ✔️ Chapter:\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 589985)}
# {'video_url': '/watch?v=gI1p1K7jF1A&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@UASocialSchool', 'username': 'Social School by Unacademy', 'title': 'Environment and Natural Resources | India’s Stand on Environmental Issues| Class 12Political Science', 'view_num': '23K', 'created_at': '1 year', 'shortdesc': "In this session, Educator Digraj Singh Rajput will be discussing India's Stand on Environmental Issues from the chapter\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 592969)}
# {'video_url': '/watch?v=icsvDMVRT3A&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@StudyPlanetbyMANISHTHAKUR', 'username': 'Study Planet', 'title': 'Global Environmental Issues | North-South Conflict on Environment | Agenda 21 | Detail Explanation', 'view_num': '34K', 'created_at': '1 year', 'shortdesc': 'globalenvironmentissues #environmentalchallenges #environmentproblems #northsouthdivision #agenda21 #riosummit\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 595858)}
# {'video_url': '/watch?v=yrO7ew1ee9k&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@LandmarkStories', 'username': 'Landmark Stories', 'title': 'Tackling Big Environmental Challenges - [Trailer]', 'view_num': '1K', 'created_at': '4 years', 'shortdesc': 'You hear about environmental issues on the news, but often not about the people working tirelessly to solve them. Join us as we\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 598877)}
# {'video_url': '/watch?v=71HNTNebMiE&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@rabiatulazman9606', 'username': 'Rabiatul Azman', 'title': 'Environmental issue in Malaysia', 'view_num': '3.9K', 'created_at': '3 years', 'shortdesc': "This is a video for educational purposes. The stock videos are credited in the end credits. I don't own the songs.", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 601738)}
# {'video_url': '/watch?v=A0pB1qw8SMs&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@worldish6181', 'username': 'WORLDISH', 'title': '10 Major Current Environmental Problems', 'view_num': '379K', 'created_at': '6 years', 'shortdesc': 'Music Attribution: At Rest - Romance by Kevin MacLeod is licensed under a Creative Commons Attribution licence\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 605706)}
# {'video_url': '/watch?v=dcgq4jaUqLE&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@POLSCHELP', 'username': 'POL SC HELP', 'title': 'GLOBAL ENVIRONMENTAL ISSUE: Climate change and Global Commons', 'view_num': '76K', 'created_at': '3 years', 'shortdesc': 'Explains global environmental issues, particularly Climate change and Global Commons, their genesis, challenges, international\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 608695)}
# {'video_url': '/watch?v=CTCEJX3d0IE&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@Sumanpreetkaur0786', 'username': 'Math With Sumanpreet Kaur', 'title': 'ENVIRONMENT ISSUES | PSSSB FOREST GUARD/VDO/CLERK | ENVIRONMENT MCQ |  ENVIRONMENT GK MCQs #psssb *3', 'view_num': '13K', 'created_at': '1 year', 'shortdesc': 'ਵਾਤਾਵਰਣ environment punjabi Environment mcq environment environment tet question ENVIRONMENT // Practice with\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 30, 611927)}
# this video has already been added.
# {'video_url': '/watch?v=4bXfDBbdqgk&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@BBCNews', 'username': 'BBC News', 'title': "Australia's environment in 'shocking' decline, report finds - BBC News", 'view_num': '133K', 'created_at': '1 year', 'shortdesc': "Australia's environment is in a shocking state and faces further decline from amplifying threats, according to an anticipated report.", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 574434)}
# {'video_url': '/watch?v=EVyXjxLceBg&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@thomaspandolfi3147', 'username': 'Thomas Pandolfi', 'title': 'Global Environmental Issues', 'view_num': '86K', 'created_at': '9 years', 'shortdesc': 'global environmental issues and challenges facing mankind.', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 577604)}
# {'video_url': '/watch?v=VdSqPMggrtY&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@EnglishPW', 'username': 'Physics Wallah - English', 'title': 'Environmental Issues 01 | Air Pollution and Its Control | Pure English | 12th/NEET/CUET', 'view_num': '4.2K', 'created_at': '1 year', 'shortdesc': 'Excellence Batch is for all the students of the NCERT Class 12th Boards /IIT-JEE | NEET | CUET Class all the notes will be\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 582603)}
# {'video_url': '/watch?v=MqermIBhzAI&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@TheAtlantic', 'username': 'The Atlantic', 'title': "What Is the Biggest Environmental Problem People Don't Know About?", 'view_num': '103K', 'created_at': '8 years', 'shortdesc': "At this year's Aspen Ideas Festival, we asked a group of scientists, activists, and filmmakers to name the largest environmental\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 586279)}
# {'video_url': '/watch?v=rkihVxeAM68&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@GetintoIAS', 'username': 'GetintoIAS', 'title': 'Environmental Issues & Health Effects | Environment | Shankar IAS Book | English | UPSC | GetintoIAS', 'view_num': '15K', 'created_at': '4 years', 'shortdesc': 'Environmental Issues and Health Effects | Environment & Ecology | Shankar IAS Book | In English | UPSC | GetintoIAS.com About\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 588826)}
# {'video_url': '/watch?v=eesBUBxH-FY&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@electricenglish', 'username': 'Electric English', 'title': 'Environmental Issues Class-1 PSSSB Forest Guard/Clerk/VDO/Excise | Environment MCQs | Environment GK', 'view_num': '7.2K', 'created_at': 'Streamed 1 year', 'shortdesc': 'Environmental Issues Class-1 PSSSB Forest Guard/Clerk/VDO/Excise | Environment MCQs | Environment GK @electricenglish\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 592827)}
# {'video_url': '/watch?v=ZqduypIBvfU&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@RakshitaSingh', 'username': 'Rakshita Singh', 'title': 'Environmental Issues One Shot | NEET 2022.', 'view_num': '104K', 'created_at': 'Streamed 1 year', 'shortdesc': 'How to score 360 in 45 Days in Biology for NEET 2022. Join Telegram for Notes: https://t.me/rakshita_singh07 Instagram:\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 596138)}
# {'video_url': '/watch?v=X2YgM1Zw4_E&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@SmileandLearnEnglish', 'username': 'Smile and Learn - English', 'title': 'How to Take Care of the Environment - 10 Ways to Take Care of the Environment', 'view_num': '1.3M', 'created_at': '3 years', 'shortdesc': 'Educational video for children to learn what the environment is and how we can look after it better. These are our ten tips and\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 600605)}
# {'video_url': '/watch?v=g-W4XDvBRDY&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@StartsWithUs', 'username': 'Starts With Us', 'title': 'The History of Environmental Issues in U.S. Politics', 'view_num': '11K', 'created_at': '7 months', 'shortdesc': 'Climate change and the environment used to be a bipartisan issue… What changed? A short history and timeline of\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 603749)}
# {'video_url': '/watch?v=FDrhP9LrjYU&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@NEET_JEEBYUTKARSHCLASSES', 'username': 'NEET & JEE by UTKARSH CLASSES', 'title': 'Environmental Issues #2 | Biology | NEET 2023 | NCERT Page By Page | Pratham Nahata Sir', 'view_num': '6.1K', 'created_at': 'Streamed 10 months', 'shortdesc': 'nahatasir #Neet&jeeByUtkarshclasses #neet2023preparation Environmental Issues #2 | Biology | NEET 2023 | NCERT Page By\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 606908)}
# {'video_url': '/watch?v=hKSHbm30up8&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@TEDx', 'username': 'TEDx Talks', 'title': 'Solution to social and environmental issues is a must for businesses | Rick Wheatley | TEDxOsloSalon', 'view_num': '6K', 'created_at': '5 years', 'shortdesc': "69 of the 100 largest economic entities on the planet are corporations, but business can't continue to be big if it doesn't take a\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 610775)}
# {'video_url': '/watch?v=oQq3axWF8o0&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@DrHariomGangwar', 'username': 'Dr. Hariom Gangwar', 'title': 'Crash Course | Environmental Issues | By Dr. Hariom Gangwar', 'view_num': '1.6K', 'created_at': '9 months', 'shortdesc': 'THANK YOU SO MUCH FOR YOUR LOVE AND SUPPORT Download NEET Abhyas\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 613726)}
# {'video_url': '/watch?v=gJNHTbkl5Ag&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@PunjabAdda247', 'username': 'Punjab Adda247', 'title': 'PSSSB Excise/VDO /Clerk Environmental Issues Most Expected Questions based on Ecosystem', 'view_num': '1.6K', 'created_at': 'Streamed 1 year', 'shortdesc': 'PSSSB Excise/VDO /Clerk Environmental Issues Most Expected Questions based on Ecosystem ****** Welcome to Punjab\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 617065)}
# {'video_url': '/watch?v=45BzLUxyggM&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@Sumanpreetkaur0786', 'username': 'Math With Sumanpreet Kaur', 'title': 'ENVIRONMENT ISSUES | PSSSB FOREST GUARD/VDO/CLERK | ENVIRONMENT MCQ |  ENVIRONMENT GK MCQs #psssb (1', 'view_num': '36K', 'created_at': '1 year', 'shortdesc': 'ਵਾਤਾਵਰਣ environment punjabi Environment mcq environment environment tet question ENVIRONMENT // Practice with\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 620275)}
# {'video_url': '/watch?v=ir-HYB34lko&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@UANeetToppers', 'username': 'Unacademy NEET Toppers', 'title': 'Environmental Issues | L1 | Saarthi | NEET 2023 | Gargi Singh', 'view_num': '8.5K', 'created_at': 'Streamed 1 year', 'shortdesc': 'In this session, Educator Gargi Singh will be discussing about Environmental Issues for NEET 2023. Watch this complete video to\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 623237)}
# {'video_url': '/watch?v=izC83wmNyOo&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@GreenEnvironments', 'username': 'Green Environments ', 'title': 'Environmental problems | Africa | environmental degradation | list of environmental issues', 'view_num': '838', 'created_at': '9 months', 'shortdesc': 'Africa is a continent that is home to a diverse range of ecosystems and wildlife, and yet it is facing numerous environmental\xa0...', 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 626231)}
# {'video_url': '/watch?v=W_hZAPlxs3g&pp=ygUUZW52aXJvbm1lbnRhbCBpc3N1ZXM%3D', 'user_url': '/@environmentcomag', 'username': 'Environment co', 'title': '6 Ways to Raise Awareness About Environmental Issues', 'view_num': '1.9K', 'created_at': '1 year', 'shortdesc': "There's no way around it. We can only protect our planet through action. This effort can't happen without educating the masses\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 629076)}
# {'video_url': '/shorts/gRDG6kFaGEk', 'user_url': '/@HumanProgressOrg', 'username': 'Human Progress', 'title': "Today's environmental problems require private-sector solutions", 'view_num': '1K', 'created_at': '8 months', 'shortdesc': "Todd Myers argues innovation—not outdated regulations—will solve today's environmental challenges. Watch the full interview:\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 632160)}
# {'video_url': '/shorts/fu513tTTs14', 'user_url': '/@TheNeetBeat', 'username': 'The NEET Beat', 'title': 'Biology XII -16 ENVIRONMENTAL ISSUES -Important Point #neet2022 #aiims #afmc #shorts #youtubeshorts', 'view_num': '16K', 'created_at': '1 year', 'shortdesc': "The 'short' contains FACTUAL Information from the NCERT Biology Class - XII that will help NEET Aspirants remember the one\xa0...", 'collected_at': datetime.datetime(2024, 1, 29, 19, 48, 39, 634926)}
# Mounted at /gdrive
# the crawling task is finished.
# the csv has been downloaded to your local computer. The program has been completed successfully.

# %%
# The url where the data will be collected from.
url = "https://www.youtube.com/results?search_query=standing+rock"

# Input the targeting url to the bot, and the bot will load data from the url.
bot.get(url)

# An array to store all the video urls. If a video has been crawled, it would not be stored to the data frame.
video_urls = []
# An array to store the retrieved video details.
results = []


# variable i indicates the number of times that scrolls down a web page. In practice, you might want to develop different
# interaction approach to load and view the web pages.

for i in range(5):

    # Create a document object model (DOM) from the raw source of the crawled web page.
    # Since you are processing a html page, 'html.parser' is chosen.
    soup = BeautifulSoup(bot.page_source, 'html.parser')

    # Capture all the video items using find_all or findAll method.
    # To view the information of the html elements you want to collect, you need to inspect the raw source using Chrome Inspector.
    # To test whether you find the right html elements, you can use the pycharm debugger to examine the returned data.
    videos = soup.find_all('ytd-video-renderer', class_="style-scope ytd-item-section-renderer")[-20:] # 20 indicates only process the newly-acquired 20 entries.

    # iterate and process each video entry.
    for video in videos:

        # I prefer use the "try-except" statement to enable the program run without pausing due to unexpected errors.
        try:
            # extract the video url, user url, username, title, view number, created time, short description, and collected time.
            # To determine the html elements, you need to inspect the raw source using Chrome Inspector. You can also use ChatGPT to find the html elements.
            video_url = video.find("a", class_="yt-simple-endpoint style-scope ytd-video-renderer").attrs["href"]
            user_url = video.find("a", class_="yt-simple-endpoint style-scope yt-formatted-string").attrs["href"]
            username = video.find("a", class_="yt-simple-endpoint style-scope yt-formatted-string").text
            title = video.find("yt-formatted-string", class_="style-scope ytd-video-renderer").text
            metadata_items = video.find_all("span", class_="inline-metadata-item style-scope ytd-video-meta-block")
            view_num = metadata_items[0].text.replace(" views", "")
            created_at = metadata_items[1].text.replace(" ago", "")
            shortdesc = video.find("yt-formatted-string", class_="metadata-snippet-text style-scope ytd-video-renderer").text
            collected_at = datetime.datetime.now()

            # create a row in the dict format.
            row = {'video_url': video_url,
                    'user_url': user_url,
                    'username': username,
                    'title': title,
                    'view_num': view_num,
                    'created_at': created_at,
                    'shortdesc': shortdesc,
                    'collected_at': collected_at}

            # if a video has been added, this video would not be inserted to the results array,
            # otherwise, this video will be inserted.
            if video_url in video_urls:
                print("this video has already been added.")
            else:
                print(row)
                video_urls.append(video_url)
                results.append(row)
        except:
            pass

    # it is very important to enable the bot take some rest, and then resume to work.
    # It will make this data collection process more human-like, otherwise, the bot will be blocked by the website.
    time.sleep(5)

    # Let the bot scrolls down to the bottom of the content element, most of the time the bot needs to scroll down to the bottom of the page.
    bot.execute_script('window.scrollTo(0,  document.getElementById("content").scrollHeight);')

# terminate the bot object.
bot.close()

# Store the results as a pandas dataframe
df = pd.DataFrame(results)

# notify the completion of the crawling in the console.
print("the crawling task is finished.")

# %%
# Create data on to Google Drive
from google.colab import drive
# Mount your Drive to the Colab VM.
#drive._mount('/gdrive')
drive.mount('/gdrive')

# the file path where to store the output csv on google drive
output_file = '/gdrive/My Drive/videos.csv'

# Save the dataframe as a csv file
df.to_csv(output_file, index=False)

# %%
# download the csv to your local computer
from google.colab import files
files.download(output_file)
print("the csv has been downloaded to your local computer. The program has been completed successfully.")
